# %%
pip install streamlit
# Out:
# Collecting streamlitNote: you may need to restart the kernel to use updated packages.
#
#   Downloading streamlit-1.28.2-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting altair<6,>=4.0 (from streamlit)
#   Downloading altair-5.1.2-py3-none-any.whl.metadata (8.6 kB)
# Collecting blinker<2,>=1.0.0 (from streamlit)
#   Downloading blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (8.1.7)
# Collecting importlib-metadata<7,>=1.4 (from streamlit)
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (1.24.2)
# Requirement already satisfied: packaging<24,>=16.8 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (4.24.4)
# Collecting pyarrow>=6.0 (from streamlit)
#   Downloading pyarrow-14.0.1-cp310-cp310-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (2.31.0)
# Collecting rich<14,>=10.14.0 (from streamlit)
#   Downloading rich-13.7.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (8.2.3)
# Collecting toml<2,>=0.10.1 (from streamlit)
#   Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (4.5.0)
# Collecting tzlocal<6,>=1.1 (from streamlit)
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators<1,>=0.2 (from streamlit)
#   Downloading validators-0.22.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
#      ---------------------------------------- 0.0/4.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.3/4.8 MB 8.9 MB/s eta 0:00:01
#      ----- ---------------------------------- 0.7/4.8 MB 8.3 MB/s eta 0:00:01
#      ------- -------------------------------- 1.0/4.8 MB 8.6 MB/s eta 0:00:01
#      ----------- ---------------------------- 1.4/4.8 MB 8.9 MB/s eta 0:00:01
#      -------------- ------------------------- 1.7/4.8 MB 9.0 MB/s eta 0:00:01
#      ----------------- ---------------------- 2.1/4.8 MB 8.8 MB/s eta 0:00:01
#      --------------------- ------------------ 2.5/4.8 MB 9.0 MB/s eta 0:00:01
#      ----------------------- ---------------- 2.8/4.8 MB 9.4 MB/s eta 0:00:01
#      ------------------------- -------------- 3.1/4.8 MB 8.6 MB/s eta 0:00:01
#      ----------------------------- ---------- 3.5/4.8 MB 8.9 MB/s eta 0:00:01
#      -------------------------------- ------- 3.8/4.8 MB 8.7 MB/s eta 0:00:01
#      ------------------------------------ --- 4.4/4.8 MB 9.1 MB/s eta 0:00:01
#      ---------------------------------------  4.8/4.8 MB 9.0 MB/s eta 0:00:01
#      ---------------------------------------- 4.8/4.8 MB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from streamlit) (6.2)
# Collecting watchdog>=2.1.5 (from streamlit)
#   Downloading watchdog-3.0.0-py3-none-win_amd64.whl (82 kB)
#      ---------------------------------------- 0.0/82.0 kB ? eta -:--:--
#      ---------------------------------------- 82.0/82.0 kB ? eta 0:00:00
# Requirement already satisfied: jinja2 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from altair<6,>=4.0->streamlit) (4.19.1)
# Collecting toolz (from altair<6,>=4.0->streamlit)
#   Downloading toolz-0.12.0-py3-none-any.whl (55 kB)
#      ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#      ---------------------------------------- 55.8/55.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=0.5 (from importlib-metadata<7,>=1.4->streamlit)
#   Downloading zipp-3.17.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.27->streamlit) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.27->streamlit) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2.27->streamlit) (2023.7.22)
# Collecting markdown-it-py>=2.2.0 (from rich<14,>=10.14.0->streamlit)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich<14,>=10.14.0->streamlit) (2.14.0)
# Collecting tzdata (from tzlocal<6,>=1.1->streamlit)
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ---------------------------------------- 0.0/341.8 kB ? eta -:--:--
#      ------------------------------------- 341.8/341.8 kB 10.7 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\diego\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.10.6)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit)
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading streamlit-1.28.2-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.4 MB 15.2 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.4 MB 11.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.2/8.4 MB 10.5 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/8.4 MB 10.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.0/8.4 MB 9.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.4 MB 10.0 MB/s eta 0:00:01
#    ------------- -------------------------- 2.8/8.4 MB 10.5 MB/s eta 0:00:01
#    --------------- ------------------------ 3.3/8.4 MB 10.5 MB/s eta 0:00:01
#    ------------------ --------------------- 3.8/8.4 MB 10.6 MB/s eta 0:00:01
#    ------------------- -------------------- 4.1/8.4 MB 10.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.6/8.4 MB 10.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.0/8.4 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 5.4/8.4 MB 10.4 MB/s eta 0:00:01
#    --------------------------- ------------ 5.9/8.4 MB 10.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.3/8.4 MB 10.3 MB/s eta 0:00:01
#    ------------------------------- -------- 6.6/8.4 MB 10.1 MB/s eta 0:00:01
#    --------------------------------- ------ 7.0/8.4 MB 10.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.4/8.4 MB 10.0 MB/s eta 0:00:01
#    ------------------------------------ --- 7.8/8.4 MB 10.1 MB/s eta 0:00:01
#    -------------------------------------- - 8.2/8.4 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 9.6 MB/s eta 0:00:00
# Downloading altair-5.1.2-py3-none-any.whl (516 kB)
#    ---------------------------------------- 0.0/516.2 kB ? eta -:--:--
#    ------------------------ --------------- 317.4/516.2 kB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 516.2/516.2 kB 8.0 MB/s eta 0:00:00
# Downloading blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.6 kB ? eta -:--:--
#    ---------------------------------------- 190.6/190.6 kB 5.8 MB/s eta 0:00:00
# Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Downloading pyarrow-14.0.1-cp310-cp310-win_amd64.whl (24.6 MB)
#    ---------------------------------------- 0.0/24.6 MB ? eta -:--:--
#     --------------------------------------- 0.4/24.6 MB 9.2 MB/s eta 0:00:03
#    - -------------------------------------- 0.7/24.6 MB 9.1 MB/s eta 0:00:03
#    - -------------------------------------- 1.1/24.6 MB 8.9 MB/s eta 0:00:03
#    -- ------------------------------------- 1.5/24.6 MB 9.6 MB/s eta 0:00:03
#    --- ------------------------------------ 1.9/24.6 MB 9.4 MB/s eta 0:00:03
#    --- ------------------------------------ 2.3/24.6 MB 9.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.8/24.6 MB 9.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.2/24.6 MB 9.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.6/24.6 MB 10.0 MB/s eta 0:00:03
#    ------ --------------------------------- 4.0/24.6 MB 9.9 MB/s eta 0:00:03
#    ------- -------------------------------- 4.4/24.6 MB 9.7 MB/s eta 0:00:03
#    ------- -------------------------------- 4.9/24.6 MB 10.0 MB/s eta 0:00:02
#    -------- ------------------------------- 5.1/24.6 MB 9.9 MB/s eta 0:00:02
#    --------- ------------------------------ 5.6/24.6 MB 9.9 MB/s eta 0:00:02
#    --------- ------------------------------ 5.9/24.6 MB 10.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.3/24.6 MB 9.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 6.7/24.6 MB 9.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.1/24.6 MB 9.9 MB/s eta 0:00:02
#    ------------ --------------------------- 7.6/24.6 MB 10.0 MB/s eta 0:00:02
#    ------------- -------------------------- 8.1/24.6 MB 10.2 MB/s eta 0:00:02
#    ------------- -------------------------- 8.5/24.6 MB 10.0 MB/s eta 0:00:02
#    -------------- ------------------------- 8.9/24.6 MB 10.0 MB/s eta 0:00:02
#    --------------- ------------------------ 9.5/24.6 MB 10.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.0/24.6 MB 10.1 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.3/24.6 MB 10.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 10.9/24.6 MB 10.2 MB/s eta 0:00:02
#    ------------------ --------------------- 11.3/24.6 MB 10.4 MB/s eta 0:00:02
#    ------------------ --------------------- 11.7/24.6 MB 10.4 MB/s eta 0:00:02
#    ------------------- -------------------- 12.1/24.6 MB 10.4 MB/s eta 0:00:02
#    -------------------- ------------------- 12.6/24.6 MB 10.6 MB/s eta 0:00:02
#    --------------------- ------------------ 13.1/24.6 MB 10.4 MB/s eta 0:00:02
#    --------------------- ------------------ 13.5/24.6 MB 10.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.9/24.6 MB 10.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.3/24.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 14.8/24.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 15.3/24.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------- -------------- 15.7/24.6 MB 10.7 MB/s eta 0:00:01
#    -------------------------- ------------- 16.0/24.6 MB 10.7 MB/s eta 0:00:01
#    -------------------------- ------------- 16.5/24.6 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 16.9/24.6 MB 10.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 17.5/24.6 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.9/24.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------------ --------- 18.5/24.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------------ --------- 18.9/24.6 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 19.5/24.6 MB 10.7 MB/s eta 0:00:01
#    -------------------------------- ------- 19.9/24.6 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 20.4/24.6 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 20.8/24.6 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.2/24.6 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 21.7/24.6 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 22.2/24.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 22.7/24.6 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------- -- 23.2/24.6 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 23.5/24.6 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 24.0/24.6 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  24.4/24.6 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  24.6/24.6 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 24.6/24.6 MB 9.9 MB/s eta 0:00:00
# Downloading rich-13.7.0-py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/240.6 kB ? eta -:--:--
#    ---------------------------------------- 240.6/240.6 kB 7.4 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.22.0-py3-none-any.whl (26 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB 3.3 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ---------------------------------------- 0.0/87.5 kB ? eta -:--:--
#    ---------------------------------------- 87.5/87.5 kB 4.8 MB/s eta 0:00:00
# Downloading zipp-3.17.0-py3-none-any.whl (7.4 kB)
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: zipp, watchdog, validators, tzdata, toolz, toml, smmap, pyarrow, mdurl, blinker, tzlocal, pydeck, markdown-it-py, importlib-metadata, gitdb, rich, gitpython, altair, streamlit
# Successfully installed altair-5.1.2 blinker-1.7.0 gitdb-4.0.11 gitpython-3.1.40 importlib-metadata-6.8.0 markdown-it-py-3.0.0 mdurl-0.1.2 pyarrow-14.0.1 pydeck-0.8.1b0 rich-13.7.0 smmap-5.0.1 streamlit-1.28.2 toml-0.10.2 toolz-0.12.0 tzdata-2023.3 tzlocal-5.2 validators-0.22.0 watchdog-3.0.0 zipp-3.17.0

# %%
import pandas as pd
pd.read_excel(rf"Data\data.xlsx")
# Out:
#       ID  CODIGO DE LA ENTIDAD  CODIGO UBIGEO INEI CODIGO PAIS   \
# 0      1                 10069              150122           PE
# 1      2                 10069              150122           PE
# 2      3                 10069              150122           PE
# 3      4                 10069              150122           PE
# 4      5                 10069              150122           PE
# ..   ...                   ...                 ...          ...
# 715  716                 10069              150122           PE
# 716  717                 10069              150122           PE
# 717  718                 10069              150122           PE
# 718  719                 10069              150122           PE
# 719  720                 10069              150122           PE
#
#                          NOMBRE DE LA UO               Fecha  CO (ug/m3)  \
# 0    Subgerencia de Desarrollo Ambiental 2021-06-01 00:00:00    2144.632
# 1    Subgerencia de Desarrollo Ambiental 2021-06-01 01:00:00    1995.877
# 2    Subgerencia de Desarrollo Ambiental 2021-06-01 02:00:00    1881.723
# 3    Subgerencia de Desarrollo Ambiental 2021-06-01 03:00:00    1956.819
# 4    Subgerencia de Desarrollo Ambiental 2021-06-01 04:00:00    1963.882
# ..                                   ...                 ...         ...
# 715  Subgerencia de Desarrollo Ambiental 2021-06-30 19:00:00    2839.294
# 716  Subgerencia de Desarrollo Ambiental 2021-06-30 20:00:00    2863.095
# 717  Subgerencia de Desarrollo Ambiental 2021-06-30 21:00:00    2562.911
# 718  Subgerencia de Desarrollo Ambiental 2021-06-30 22:00:00    2255.425
# 719  Subgerencia de Desarrollo Ambiental 2021-06-30 23:00:00    2028.103
#
#      H2S (ug/m3)  NO2 (ug/m3)  O3 (ug/m3)  PM10 (ug/m3)  PM2.5 (ug/m3)  \
# 0         16.133       33.070      30.859        13.017          5.776
# 1         16.456       30.388      28.658        13.558          6.172
# 2         15.913       24.257      32.899        11.002          5.421
# 3         16.314       25.568      30.060         7.927          4.452
# 4         16.702       26.489      32.213         7.806          4.438
# ..           ...          ...         ...           ...            ...
# 715       21.734       35.050      43.308         4.661          2.473
# 716       21.128       33.874      42.060         5.410          3.221
# 717       20.366       32.275      41.872         6.992          4.227
# 718       20.345       29.695      33.556         5.847          3.886
# 719       20.857       27.734      35.089         5.563          3.888
#
#      SO2 (ug/m3)  Ruido (dB)   UV  Humedad (%)    Latitud   Longitud  \
# 0          5.287      73.732  0.0         96.1 -12.119134 -77.028848
# 1          4.452      64.066  0.0         96.1 -12.119134 -77.028848
# 2          4.109      69.008  0.0         96.1 -12.119134 -77.028848
# 3          3.978      76.319  0.0         96.1 -12.119134 -77.028848
# 4          4.242      69.768  0.0         96.1 -12.119134 -77.028848
# ..           ...         ...  ...          ...        ...        ...
# 715       13.452      91.626  0.0         96.1 -12.119134 -77.028848
# 716       13.973      93.254  0.0         96.1 -12.119134 -77.028848
# 717       11.308      91.361  0.0         96.1 -12.119134 -77.028848
# 718        8.178      84.400  0.0         96.1 -12.119134 -77.028848
# 719        6.133      90.502  0.0         96.1 -12.119134 -77.028848
#
#      Presion (Pa)  Temperatura (C)
# 0        1004.897           16.663
# 1        1004.699           16.575
# 2        1004.274           16.682
# 3        1003.591           16.594
# 4        1003.239           16.509
# ..            ...              ...
# 715      1003.648           15.511
# 716      1003.968           15.649
# 717      1004.227           15.776
# 718      1004.803           15.741
# 719      1005.301           15.591
#
# [720 rows x 20 columns]

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns




#Cargar la data 
#eliminé los saltos de línea en los encabezados de data.xlsx
@st.cache
def load_data():
    try:
        data = pd.read_excel(rf"Data\data.xlsx")
        return data
    except Exception as e:
        st.error(f"Error al cargar la data: {e}")
        return pd.DataFrame()  

df = load_data()

st.title('Monitoreo de calidad de aire QAIRA')

st.info('El presente dashboard contiene información de variables usadas para monitorear la calidad del aire durante el mes de Junio 2021 en el Ovalo de Miraflores - Lima, Perú.', icon="ℹ️")

st.link_button("Ir al dataset",  "https://www.datosabiertos.gob.pe/dataset/monitoreo-de-calidad-de-aire-qaira%C2%A0-municipalidad-de-miraflores/resource/5ccaf849-33a6-46ff")

st.markdown('<h3 style="color:navy;">1. Datos en tabla (listos para descargar)</h3>', unsafe_allow_html=True)
st.write(df)


pollutants = ['CO (ug/m3)', 'H2S (ug/m3)', 'NO2 (ug/m3)', 'O3 (ug/m3)', 
              'PM10 (ug/m3)', 'PM2.5 (ug/m3)', 'SO2 (ug/m3)']

pollutants_mean = df[pollutants].mean().sort_values(ascending=False)


#Gráfico de barras de los contaminantes 
#pollutants_mean = df[pollutants].mean()
#st.write('Promedio de las variables contaminantes')
#st.bar_chart(pollutants_mean)

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el gráfico de barras
fig, ax = plt.subplots(figsize=(10, 6))
bar_plot = sns.barplot(x=pollutants_mean.index, y=pollutants_mean.values, palette="Blues_r")

# Añadir etiquetas encima de cada barra
for index, value in enumerate(pollutants_mean.values):
    bar_plot.text(index, value + 0.5, round(value, 2), ha='center', va='bottom', fontsize=10)

st.divider()

# Configurar el estilo del gráfico
ax.set(ylabel='Promedio (ug/m3)', xlabel='')
st.markdown('<h3 style="color:navy;">2. Promedio de las variables contaminantes</h3>', unsafe_allow_html=True)
ax.title.set_fontsize(20)
# Mostrar el gráfico en Streamlit
st.pyplot(fig)


st.divider()
#GRAFICO 2: Lineas de tendencia para Humedad, Presión y Temperatura-----------
st.markdown('<h3 style="color:navy;">3. Lineas de tendencia para Humedad, Presión y Temperatura por Día</h3>', unsafe_allow_html=True)

st.info('Seleccione un range de fechas para filtrar las tendencias. Seleccione el rango de escala de eje Y para visualizar mejor cada gráfico.', icon="ℹ️")


df['Fecha'] = pd.to_datetime(df['Fecha'])
daily_means = df.set_index('Fecha').resample('D')[['Humedad (%)', 'Presion (Pa)', 'Temperatura (C)']].mean()


#for column in daily_means.columns:
#    st.line_chart(daily_means[column])


# Asignar una fecha por defecto
default_date = pd.to_datetime('2021-06-01')
default_date2 = pd.to_datetime('2021-06-30')
# Crear el widget date_input con la fecha por defecto
#selected_date = st.date_input('Seleccione una fecha', min_value=df['Fecha'].min(), max_value=df['Fecha'].max(), value=default_date)



# Crear el widget date_input para seleccionar el rango de fechas
date_range = st.date_input('Seleccione el rango de fechas', 
                           min_value=df['Fecha'].min(), 
                           max_value=df['Fecha'].max(), 
                           value=(default_date, default_date2))

# Obtener las fechas de inicio y fin del rango seleccionado
start_date, end_date = date_range

# Filtrar el DataFrame según el rango de fechas seleccionado
filtered_data = daily_means.loc[start_date:end_date]



import altair as alt

st.write('##### Humedad Promedio por Día')
# Personalizar la escala del eje X
y_axis_scale = st.slider('Escala del Eje Y', min_value=0, max_value=100, value=(0,110))

# Filtrar datos según el rango de fechas seleccionado en el eje X
#filtered_data = filtered_data.iloc[y_axis_scale[0]:y_axis_scale[1]]
#for column in filtered_data.columns:
#    st.line_chart(filtered_data[column], use_container_width=True, height=400 ) 

#st.line_chart(filtered_data, use_container_width=True, height=400, key='custom_chart', y_axis_scale=(0, y_axis_scale))
chart = alt.Chart(filtered_data['Humedad (%)'].reset_index()).mark_line(strokeWidth=3).encode(
    x='Fecha:T',
    y=alt.Y('Humedad (%)', scale=alt.Scale(domain=[y_axis_scale[0], y_axis_scale[1]])),
)

st.altair_chart(chart, use_container_width=True)


st.write('##### Presión Promedio por Día')
y_axis_scale2 = st.slider('Escala del Eje Y', min_value=950, max_value=1050, value=(950,1050))
chart2 = alt.Chart(filtered_data['Presion (Pa)'].reset_index()).mark_line(strokeWidth=3).encode(
    x='Fecha:T',
    y=alt.Y('Presion (Pa)', scale=alt.Scale(domain=[y_axis_scale2[0], y_axis_scale2[1]])),
)
st.altair_chart(chart2, use_container_width=True)

st.write('##### Temperatura Promedio por Día')
y_axis_scale3 = st.slider('Escala del Eje Y', min_value=0, max_value=30, value=(0,30))
chart3 = alt.Chart(filtered_data['Temperatura (C)'].reset_index()).mark_line(strokeWidth=3).encode(
    x='Fecha:T',
    y=alt.Y('Temperatura (C)', scale=alt.Scale(domain=[y_axis_scale3[0], y_axis_scale3[1]])),
)
st.altair_chart(chart3, use_container_width=True)

st.divider()

#GRAFICO 3: Mapa de Calor de Temperatura (No me muestra)
st.markdown('<h3 style="color:navy;">4. Mapa de Calor de Temperatura por Día de la semana y Hora</h3>', unsafe_allow_html=True)
temperature_pivot = df.pivot_table(
    values='Temperatura (C)', 
    index=df['Fecha'].dt.hour, 
    columns=df['Fecha'].dt.day_name(),
    aggfunc='mean'
)

plt.figure(figsize=(10, 8))
sns.heatmap(temperature_pivot, cmap='coolwarm', annot=True)
plt.xlabel('WeekDay')
plt.ylabel('Hour')
st.pyplot(plt)
# Out:
# 2023-11-24 15:05:57.217
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\Diego\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:361, in _CodeHasher.to_bytes(self, obj, context)
#     359 try:
#     360     # Hash the input
# --> 361     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     363     # Hmmm... It's possible that the size calculation is wrong. When we
#     364     # call to_bytes inside _to_bytes things get double-counted.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:622, in _CodeHasher._to_bytes(self, obj, context)
#     621 assert code is not None
# --> 622 if self._file_should_be_hashed(code.co_filename):
#     623     context = _get_context(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:403, in _CodeHasher._file_should_be_hashed(self, filename)
#     401     return False
#     402 return file_util.file_is_in_folder_glob(
# --> 403     filepath, self._get_main_script_directory()
#     404 ) or file_util.file_in_pythonpath(filepath)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:709, in _CodeHasher._get_main_script_directory()
#     707 # This works because we set __main__.__file__ to the
#     708 # script path in ScriptRunner.
# --> 709 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     710 return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# c:\Users\Diego\Desktop\IA_PUCP\Python_para_DS\TrabajoFinal\code1.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a>         st.error(f"Error al cargar la data: {e}")
#      <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>         return pd.DataFrame()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> df = load_data()
#      <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a> st.title('Monitoreo de calidad de aire QAIRA')
#      <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W2sZmlsZQ%3D%3D?line=23'>24</a> st.info('El presente dashboard contiene información de variables usadas para monitorear la calidad del aire durante el mes de Junio 2021 en el Ovalo de Miraflores - Lima, Perú.', icon="ℹ️")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\caching.py:716, in cache.<locals>.wrapped_func(*args, **kwargs)
#     714 if show_spinner:
#     715     with spinner(message, cache=True):
# --> 716         return get_or_create_cached_value()
#     717 else:
#     718     return get_or_create_cached_value()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\caching.py:638, in cache.<locals>.wrapped_func.<locals>.get_or_create_cached_value()
#     631 nonlocal cache_key
#     632 if cache_key is None:
#     633     # Delay generating the cache key until the first call.
#     634     # This way we can see values of globals, including functions
#     635     # defined after this one.
#     636     # If we generated the key earlier we would only hash those
#     637     # globals by name, and miss changes in their code or value.
# --> 638     cache_key = _hash_func(non_optional_func, hash_funcs)
#     640 # First, get the cache that's attached to this function.
#     641 # This cache's key is generated (above) from the function's code.
#     642 mem_cache = _mem_caches.get_cache(cache_key, max_entries, ttl)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\caching.py:768, in _hash_func(func, hash_funcs)
#     757 update_hash(
#     758     (func.__module__, func.__qualname__),
#     759     hasher=func_hasher,
#    (...)
#     762     hash_source=func,
#     763 )
#     765 # Include the function's body in the hash. We *do* pass hash_funcs here,
#     766 # because this step will be hashing any objects referenced in the function
#     767 # body.
# --> 768 update_hash(
#     769     func,
#     770     hasher=func_hasher,
#     771     hash_funcs=hash_funcs,
#     772     hash_reason=HashReason.CACHING_FUNC_BODY,
#     773     hash_source=func,
#     774 )
#     775 cache_key = func_hasher.hexdigest()
#     776 _LOGGER.debug(
#     777     "mem_cache key for %s.%s: %s", func.__module__, func.__qualname__, cache_key
#     778 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:109, in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     106 hash_stacks.current.hash_source = hash_source
#     108 ch = _CodeHasher(hash_funcs)
# --> 109 ch.update(hasher, val, context)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:386, in _CodeHasher.update(self, hasher, obj, context)
#     384 def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     385     """Update the provided hasher with the hash of an object."""
# --> 386     b = self.to_bytes(obj, context)
#     387     hasher.update(b)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:375, in _CodeHasher.to_bytes(self, obj, context)
#     372     raise
#     374 except Exception as ex:
# --> 375     raise InternalHashError(ex, obj)
#     377 finally:
#     378     # In case an UnhashableTypeError (or other) error is thrown, clean up the
#     379     # stack so we don't get false positives in future hashing calls
#     380     hash_stacks.current.pop()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:361, in _CodeHasher.to_bytes(self, obj, context)
#     357 hash_stacks.current.push(obj)
#     359 try:
#     360     # Hash the input
# --> 361     b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     363     # Hmmm... It's possible that the size calculation is wrong. When we
#     364     # call to_bytes inside _to_bytes things get double-counted.
#     365     self.size += sys.getsizeof(b)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:622, in _CodeHasher._to_bytes(self, obj, context)
#     620 code = getattr(obj, "__code__", None)
#     621 assert code is not None
# --> 622 if self._file_should_be_hashed(code.co_filename):
#     623     context = _get_context(obj)
#     624     defaults = getattr(obj, "__defaults__", None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:403, in _CodeHasher._file_should_be_hashed(self, filename)
#     400 if file_is_blacklisted:
#     401     return False
#     402 return file_util.file_is_in_folder_glob(
# --> 403     filepath, self._get_main_script_directory()
#     404 ) or file_util.file_in_pythonpath(filepath)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\streamlit\runtime\legacy_caching\hashing.py:709, in _CodeHasher._get_main_script_directory()
#     705 import __main__
#     707 # This works because we set __main__.__file__ to the
#     708 # script path in ScriptRunner.
# --> 709 abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     710 return str(abs_main_path.parent)
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x0000028FE6F84550>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel(rf"Data\data.xlsx")

df['Fecha'] = pd.to_datetime(df['Fecha'])

# Asignar una fecha por defecto
start_date = pd.to_datetime('2021-06-01')
end_date = pd.to_datetime('2021-06-30')

# %%
# Filtrar el DataFrame según el rango de fechas seleccionado
evolution_data = df.loc[start_date:end_date]

# Calcular la variación diaria para Humedad, Presión y Temperatura
evolution_data['Variacion Humedad'] = evolution_data['Humedad (%)'].diff()
evolution_data['Variacion Presion'] = evolution_data['Presion (Pa)'].diff()
evolution_data['Variacion Temperatura'] = evolution_data['Temperatura (C)'].diff()

# Configurar el estilo de seaborn
sns.set(style="whitegrid")

# Crear el gráfico de líneas
fig_variation, ax_variation = plt.subplots(figsize=(10, 6))

# Graficar la variación diaria de la humedad
sns.lineplot(x='Fecha', y='Variacion Humedad', data=evolution_data, label='Variación Humedad', ax=ax_variation)

# Graficar la variación diaria de la presión
sns.lineplot(x='Fecha', y='Variacion Presion', data=evolution_data, label='Variación Presión', ax=ax_variation)

# Graficar la variación diaria de la temperatura
sns.lineplot(x='Fecha', y='Variacion Temperatura', data=evolution_data, label='Variación Temperatura', ax=ax_variation)

# Configurar las etiquetas y el título
ax_variation.set(xlabel='Fecha', ylabel='Variación Diaria', title='Variación Diaria de Humedad, Presión y Temperatura')
ax_variation.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6680, in Index.get_slice_bound(self, label, side, kind)
#    6679 try:
# -> 6680     slc = self.get_loc(label)
#    6681 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: Timestamp('2021-06-01 00:00:00')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Diego\Desktop\IA_PUCP\Python_para_DS\TrabajoFinal\code1.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Filtrar el DataFrame según el rango de fechas seleccionado
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> evolution_data = df.loc[start_date:end_date]
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W3sZmlsZQ%3D%3D?line=3'>4</a> # Calcular la variación diaria para Humedad, Presión y Temperatura
#       <a href='vscode-notebook-cell:/c%3A/Users/Diego/Desktop/IA_PUCP/Python_para_DS/TrabajoFinal/code1.ipynb#W3sZmlsZQ%3D%3D?line=4'>5</a> evolution_data['Variacion Humedad'] = evolution_data['Humedad (%)'].diff()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1290, in _LocIndexer._getitem_axis(self, key, axis)
#    1288 if isinstance(key, slice):
#    1289     self._validate_key(key, axis)
# -> 1290     return self._get_slice_axis(key, axis=axis)
#    1291 elif com.is_bool_indexer(key):
#    1292     return self._getbool_axis(key, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexing.py:1324, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1321     return obj.copy(deep=False)
#    1323 labels = obj._get_axis(axis)
# -> 1324 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1326 if isinstance(indexer, slice):
#    1327     return self.obj._slice(indexer, axis=axis)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6559, in Index.slice_indexer(self, start, end, step, kind)
#    6516 """
#    6517 Compute the slice indexer for input labels and step.
#    6518
#    (...)
#    6555 slice(1, 3, None)
#    6556 """
#    6557 self._deprecated_arg(kind, "kind", "slice_indexer")
# -> 6559 start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6561 # return a slice
#    6562 if not is_scalar(start_slice):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6767, in Index.slice_locs(self, start, end, step, kind)
#    6765 start_slice = None
#    6766 if start is not None:
# -> 6767     start_slice = self.get_slice_bound(start, "left")
#    6768 if start_slice is None:
#    6769     start_slice = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6683, in Index.get_slice_bound(self, label, side, kind)
#    6681 except KeyError as err:
#    6682     try:
# -> 6683         return self._searchsorted_monotonic(label, side)
#    6684     except ValueError:
#    6685         # raise the original KeyError
#    6686         raise err
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6629, in Index._searchsorted_monotonic(self, label, side)
#    6627 def _searchsorted_monotonic(self, label, side: Literal["left", "right"] = "left"):
#    6628     if self.is_monotonic_increasing:
# -> 6629         return self.searchsorted(label, side=side)
#    6630     elif self.is_monotonic_decreasing:
#    6631         # np.searchsorted expects ascending sort order, have to reverse
#    6632         # everything for it to work (element ordering, search side and
#    6633         # resulting value).
#    6634         pos = self[::-1].searchsorted(
#    6635             label, side="right" if side == "left" else "left"
#    6636         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\base.py:1298, in IndexOpsMixin.searchsorted(self, value, side, sorter)
#    1294 if not isinstance(values, np.ndarray):
#    1295     # Going through EA.searchsorted directly improves performance GH#38083
#    1296     return values.searchsorted(value, side=side, sorter=sorter)
# -> 1298 return algorithms.searchsorted(
#    1299     values,
#    1300     value,
#    1301     side=side,
#    1302     sorter=sorter,
#    1303 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\algorithms.py:1669, in searchsorted(arr, value, side, sorter)
#    1665     arr = ensure_wrapped_if_datetimelike(arr)
#    1667 # Argument 1 to "searchsorted" of "ndarray" has incompatible type
#    1668 # "Union[NumpyValueArrayLike, ExtensionArray]"; expected "NumpyValueArrayLike"
# -> 1669 return arr.searchsorted(value, side=side, sorter=sorter)
#
# TypeError: '<' not supported between instances of 'int' and 'Timestamp'

# %%
df.set_index('Fecha', inplace=True)

# %%
# Filtrar el DataFrame según el rango de fechas seleccionado
evolution_data = df.loc[start_date:end_date]
